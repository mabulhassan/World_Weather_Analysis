# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests
# Import the time library
import time
# Import the datetime module from the datetime library
from datetime import datetime
# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        country= city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | akyab
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | taoudenni
# Processing Record 6 of Set 1 | broome
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | bowen
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | olafsvik
# Processing Record 13 of Set 1 | kailua
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | seydi
# Processing Record 19 of Set 1 | guerrero negro
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | abay
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | moses lake
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | saint-pierre
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | veraval
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | batagay
# Processing Record 34 of Set 1 | aklavik
# Processing Record 35 of Set 1 | iisalmi
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | skalat
# Processing Record 39 of Set 1 | sioux lookout
# Processing Record 40 of Set 1 | katherine
# Processing Record 41 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 1 | fairmont
# Processing Record 43 of Set 1 | greenville
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | basoko
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | beringovskiy
# Processing Record 1 of Set 2 | aitape
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | launceston
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | kasongo-lunda
# Processing Record 13 of Set 2 | te anau
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | lorengau
# Processing Record 16 of Set 2 | kemijarvi
# Processing Record 17 of Set 2 | zyryanka
# Processing Record 18 of Set 2 | plettenberg bay
# Processing Record 19 of Set 2 | lahat
# Processing Record 20 of Set 2 | gornyye klyuchi
# Processing Record 21 of Set 2 | luba
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | olean
# Processing Record 24 of Set 2 | atar
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | guanica
# Processing Record 30 of Set 2 | constitucion
# Processing Record 31 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | muttupet
# Processing Record 34 of Set 2 | kiunga
# Processing Record 35 of Set 2 | cairns
# Processing Record 36 of Set 2 | umm kaddadah
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | magistralnyy
# Processing Record 39 of Set 2 | ahuimanu
# Processing Record 40 of Set 2 | dunedin
# Processing Record 41 of Set 2 | porto novo
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | donegal
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | lapeer
# Processing Record 1 of Set 3 | nelson bay
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | ostersund
# Processing Record 4 of Set 3 | kitakata
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | salinopolis
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | sobolevo
# Processing Record 10 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | dudinka
# Processing Record 12 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | bathsheba
# Processing Record 18 of Set 3 | korostyshiv
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | touros
# Processing Record 21 of Set 3 | nizhnevartovsk
# Processing Record 22 of Set 3 | clyde river
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | weligama
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | margate
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | athabasca
# Processing Record 29 of Set 3 | granadilla de abona
# Processing Record 30 of Set 3 | homagama
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | merauke
# Processing Record 39 of Set 3 | poum
# Processing Record 40 of Set 3 | qaqortoq
# Processing Record 41 of Set 3 | saint george
# Processing Record 42 of Set 3 | fort dodge
# Processing Record 43 of Set 3 | aksarka
# Processing Record 44 of Set 3 | bolu
# Processing Record 45 of Set 3 | rio grande
# Processing Record 46 of Set 3 | moron
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | acapulco
# Processing Record 49 of Set 3 | bilibino
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | cruzeiro
# Processing Record 2 of Set 4 | qasigiannguit
# Processing Record 3 of Set 4 | lunglei
# Processing Record 4 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 4 | glendive
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 4 | san jeronimo
# Processing Record 8 of Set 4 | kosh-agach
# Processing Record 9 of Set 4 | iracemapolis
# Processing Record 10 of Set 4 | solnechnyy
# Processing Record 11 of Set 4 | matara
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | sola
# Processing Record 14 of Set 4 | emerald
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | semey
# Processing Record 18 of Set 4 | kysyl-syr
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | belmonte
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 4 | lerwick
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | choucheng
# City not found. Skipping...
# Processing Record 28 of Set 4 | okato
# Processing Record 29 of Set 4 | parrita
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | voh
# Processing Record 32 of Set 4 | wanning
# Processing Record 33 of Set 4 | paita
# Processing Record 34 of Set 4 | banda aceh
# Processing Record 35 of Set 4 | camacha
# Processing Record 36 of Set 4 | crestview
# Processing Record 37 of Set 4 | maniitsoq
# Processing Record 38 of Set 4 | kinarut
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | linhares
# Processing Record 41 of Set 4 | gambela
# Processing Record 42 of Set 4 | xichang
# Processing Record 43 of Set 4 | astakos
# Processing Record 44 of Set 4 | farim
# Processing Record 45 of Set 4 | bikin
# Processing Record 46 of Set 4 | eravur
# Processing Record 47 of Set 4 | matagami
# Processing Record 48 of Set 4 | naica
# Processing Record 49 of Set 4 | sharjah
# Processing Record 50 of Set 4 | kerman
# Processing Record 1 of Set 5 | brae
# Processing Record 2 of Set 5 | laguna
# Processing Record 3 of Set 5 | tabuk
# Processing Record 4 of Set 5 | todos santos
# Processing Record 5 of Set 5 | east wenatchee bench
# Processing Record 6 of Set 5 | barcelona
# Processing Record 7 of Set 5 | la palma
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | komsomolskiy
# Processing Record 11 of Set 5 | antofagasta
# Processing Record 12 of Set 5 | antalaha
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | chemainus
# Processing Record 17 of Set 5 | concordia
# Processing Record 18 of Set 5 | champerico
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | yerbogachen
# Processing Record 22 of Set 5 | dimitrovgrad
# Processing Record 23 of Set 5 | miri
# Processing Record 24 of Set 5 | maungatapere
# Processing Record 25 of Set 5 | abha
# Processing Record 26 of Set 5 | kukes
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | kudahuvadhoo
# Processing Record 33 of Set 5 | soyo
# Processing Record 34 of Set 5 | haines junction
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | camana
# Processing Record 37 of Set 5 | puerto del rosario
# Processing Record 38 of Set 5 | colan
# Processing Record 39 of Set 5 | zhicheng
# Processing Record 40 of Set 5 | south lake tahoe
# Processing Record 41 of Set 5 | fairbanks
# Processing Record 42 of Set 5 | katobu
# Processing Record 43 of Set 5 | kumbo
# Processing Record 44 of Set 5 | sao joao da barra
# Processing Record 45 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 5 | tiarei
# Processing Record 47 of Set 5 | inirida
# Processing Record 48 of Set 5 | goure
# Processing Record 49 of Set 5 | kokopo
# Processing Record 50 of Set 5 | khatanga
# Processing Record 1 of Set 6 | glyadyanskoye
# Processing Record 2 of Set 6 | valdivia
# Processing Record 3 of Set 6 | stephenville
# Processing Record 4 of Set 6 | syamzha
# Processing Record 5 of Set 6 | san juan bautista
# Processing Record 6 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 6 | camopi
# Processing Record 8 of Set 6 | casablanca
# Processing Record 9 of Set 6 | astana
# Processing Record 10 of Set 6 | ayan
# Processing Record 11 of Set 6 | swan hill
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | bambous virieux
# Processing Record 14 of Set 6 | puerto quijarro
# Processing Record 15 of Set 6 | port augusta
# Processing Record 16 of Set 6 | meiganga
# Processing Record 17 of Set 6 | mlonggo
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | sosnovo-ozerskoye
# Processing Record 20 of Set 6 | ouesso
# Processing Record 21 of Set 6 | hervey bay
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | jerantut
# Processing Record 24 of Set 6 | san jose
# Processing Record 25 of Set 6 | hobyo
# Processing Record 26 of Set 6 | alekseyevsk
# Processing Record 27 of Set 6 | egvekinot
# Processing Record 28 of Set 6 | lasa
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | angoche
# Processing Record 31 of Set 6 | daru
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | tiznit
# Processing Record 34 of Set 6 | half moon bay
# Processing Record 35 of Set 6 | methoni
# Processing Record 36 of Set 6 | green river
# Processing Record 37 of Set 6 | sur
# Processing Record 38 of Set 6 | rundu
# Processing Record 39 of Set 6 | hukuntsi
# Processing Record 40 of Set 6 | chokurdakh
# Processing Record 41 of Set 6 | pevek
# Processing Record 42 of Set 6 | heers
# Processing Record 43 of Set 6 | lac-au-saumon
# Processing Record 44 of Set 6 | ushtobe
# Processing Record 45 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | san andres
# Processing Record 48 of Set 6 | goundam
# Processing Record 49 of Set 6 | moerai
# Processing Record 50 of Set 6 | iqaluit
# Processing Record 1 of Set 7 | maragogi
# Processing Record 2 of Set 7 | wahiawa
# Processing Record 3 of Set 7 | sorland
# Processing Record 4 of Set 7 | hearst
# Processing Record 5 of Set 7 | ngunguru
# Processing Record 6 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | buta
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | richards bay
# Processing Record 12 of Set 7 | fairlie
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | nouadhibou
# Processing Record 16 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 7 | kununurra
# Processing Record 18 of Set 7 | barrow
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | udachnyy
# Processing Record 21 of Set 7 | sragen
# Processing Record 22 of Set 7 | avera
# Processing Record 23 of Set 7 | turayf
# Processing Record 24 of Set 7 | guicheng
# City not found. Skipping...
# Processing Record 25 of Set 7 | gizo
# Processing Record 26 of Set 7 | dzhebariki-khaya
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | college
# Processing Record 29 of Set 7 | barnova
# Processing Record 30 of Set 7 | frederico westphalen
# Processing Record 31 of Set 7 | matai
# Processing Record 32 of Set 7 | madimba
# Processing Record 33 of Set 7 | erdenet
# Processing Record 34 of Set 7 | namatanai
# Processing Record 35 of Set 7 | manggar
# Processing Record 36 of Set 7 | bukama
# Processing Record 37 of Set 7 | alihe
# Processing Record 38 of Set 7 | la seyne-sur-mer
# Processing Record 39 of Set 7 | xam nua
# Processing Record 40 of Set 7 | mudgee
# Processing Record 41 of Set 7 | na wa
# Processing Record 42 of Set 7 | cozumel
# Processing Record 43 of Set 7 | whitehorse
# Processing Record 44 of Set 7 | gazojak
# Processing Record 45 of Set 7 | funadhoo
# Processing Record 46 of Set 7 | acopiara
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | vanimo
# Processing Record 49 of Set 7 | alto araguaia
# Processing Record 50 of Set 7 | berdigestyakh
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | marshall
# Processing Record 3 of Set 8 | sept-iles
# Processing Record 4 of Set 8 | andros town
# Processing Record 5 of Set 8 | nara
# Processing Record 6 of Set 8 | shache
# Processing Record 7 of Set 8 | vilcun
# Processing Record 8 of Set 8 | klaksvik
# Processing Record 9 of Set 8 | clonmel
# Processing Record 10 of Set 8 | tilichiki
# Processing Record 11 of Set 8 | loding
# Processing Record 12 of Set 8 | ranong
# Processing Record 13 of Set 8 | fond du lac
# Processing Record 14 of Set 8 | batasan
# Processing Record 15 of Set 8 | port moresby
# Processing Record 16 of Set 8 | rantepao
# Processing Record 17 of Set 8 | vila
# Processing Record 18 of Set 8 | mitsamiouli
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | coari
# Processing Record 21 of Set 8 | warrnambool
# Processing Record 22 of Set 8 | coracora
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | clearlake
# Processing Record 25 of Set 8 | high level
# Processing Record 26 of Set 8 | shasta lake
# Processing Record 27 of Set 8 | nuevo progreso
# Processing Record 28 of Set 8 | hovd
# Processing Record 29 of Set 8 | pangkalanbuun
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | benguela
# Processing Record 32 of Set 8 | namibe
# Processing Record 33 of Set 8 | mweka
# Processing Record 34 of Set 8 | cabedelo
# Processing Record 35 of Set 8 | bonavista
# Processing Record 36 of Set 8 | kuala terengganu
# Processing Record 37 of Set 8 | plouzane
# Processing Record 38 of Set 8 | mikhaylovka
# Processing Record 39 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 8 | hay river
# Processing Record 41 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 8 | setermoen
# Processing Record 43 of Set 8 | torbay
# Processing Record 44 of Set 8 | imbituba
# Processing Record 45 of Set 8 | tiksi
# Processing Record 46 of Set 8 | chingirlau
# Processing Record 47 of Set 8 | san patricio
# Processing Record 48 of Set 8 | heinola
# Processing Record 49 of Set 8 | raga
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 9 | goalpara
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | yulara
# Processing Record 7 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 9 | whitianga
# Processing Record 9 of Set 9 | hirtshals
# Processing Record 10 of Set 9 | severodvinsk
# Processing Record 11 of Set 9 | campbell river
# Processing Record 12 of Set 9 | marzuq
# Processing Record 13 of Set 9 | nohar
# Processing Record 14 of Set 9 | burgeo
# Processing Record 15 of Set 9 | kutum
# Processing Record 16 of Set 9 | miyako
# Processing Record 17 of Set 9 | dangriga
# Processing Record 18 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 9 | zdvinsk
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | the valley
# Processing Record 22 of Set 9 | bambanglipuro
# Processing Record 23 of Set 9 | wanaka
# Processing Record 24 of Set 9 | paamiut
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | bandraboua
# Processing Record 27 of Set 9 | kholbon
# Processing Record 28 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 9 | sorong
# Processing Record 30 of Set 9 | cranbrook
# Processing Record 31 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | elat
# Processing Record 33 of Set 9 | kanpur
# Processing Record 34 of Set 9 | nisia floresta
# Processing Record 35 of Set 9 | westport
# Processing Record 36 of Set 9 | kalmunai
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | aksakovo
# Processing Record 39 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 41 of Set 9 | pisco
# Processing Record 42 of Set 9 | kenai
# Processing Record 43 of Set 9 | soe
# Processing Record 44 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 9 | menongue
# Processing Record 46 of Set 9 | harper
# Processing Record 47 of Set 9 | ndjole
# Processing Record 48 of Set 9 | marsh harbour
# Processing Record 49 of Set 9 | sumen
# City not found. Skipping...
# Processing Record 50 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 10 | port-gentil
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | dikson
# Processing Record 5 of Set 10 | challapata
# Processing Record 6 of Set 10 | impfondo
# Processing Record 7 of Set 10 | arlit
# Processing Record 8 of Set 10 | chesma
# Processing Record 9 of Set 10 | gubkinskiy
# Processing Record 10 of Set 10 | tacuarembo
# Processing Record 11 of Set 10 | crotone
# Processing Record 12 of Set 10 | beruwala
# Processing Record 13 of Set 10 | newport
# Processing Record 14 of Set 10 | hailey
# Processing Record 15 of Set 10 | puerto baquerizo moreno
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | mutoko
# Processing Record 18 of Set 10 | tual
# Processing Record 19 of Set 10 | turukhansk
# Processing Record 20 of Set 10 | sungaipenuh
# Processing Record 21 of Set 10 | maarianhamina
# Processing Record 22 of Set 10 | lazaro cardenas
# Processing Record 23 of Set 10 | vila velha
# Processing Record 24 of Set 10 | berlevag
# Processing Record 25 of Set 10 | bosaso
# Processing Record 26 of Set 10 | miracema do tocantins
# Processing Record 27 of Set 10 | hualmay
# Processing Record 28 of Set 10 | pahrump
# Processing Record 29 of Set 10 | otacilio costa
# Processing Record 30 of Set 10 | faanui
# Processing Record 31 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 10 | alyangula
# Processing Record 33 of Set 10 | porto nacional
# Processing Record 34 of Set 10 | hwange
# Processing Record 35 of Set 10 | rockhampton
# Processing Record 36 of Set 10 | mandalgovi
# Processing Record 37 of Set 10 | general roca
# Processing Record 38 of Set 10 | rudnogorsk
# Processing Record 39 of Set 10 | kihei
# Processing Record 40 of Set 10 | zemio
# Processing Record 41 of Set 10 | abu kamal
# Processing Record 42 of Set 10 | shaunavon
# Processing Record 43 of Set 10 | keuruu
# Processing Record 44 of Set 10 | mangan
# Processing Record 45 of Set 10 | fortuna
# Processing Record 46 of Set 10 | iranshahr
# Processing Record 47 of Set 10 | ternate
# Processing Record 48 of Set 10 | angola
# Processing Record 49 of Set 10 | bay roberts
# Processing Record 50 of Set 10 | jalu
# Processing Record 1 of Set 11 | gornopravdinsk
# Processing Record 2 of Set 11 | ampanihy
# Processing Record 3 of Set 11 | mata
# Processing Record 4 of Set 11 | cesme
# Processing Record 5 of Set 11 | talara
# Processing Record 6 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 11 | lagoa
# Processing Record 8 of Set 11 | djibo
# Processing Record 9 of Set 11 | airai
# Processing Record 10 of Set 11 | kaduna
# Processing Record 11 of Set 11 | nokaneng
# Processing Record 12 of Set 11 | oktyabrskoye
# Processing Record 13 of Set 11 | riwaka
# Processing Record 14 of Set 11 | west wendover
# Processing Record 15 of Set 11 | naantali
# Processing Record 16 of Set 11 | manutuke
# Processing Record 17 of Set 11 | tagusao
# Processing Record 18 of Set 11 | tura
# Processing Record 19 of Set 11 | talas
# Processing Record 20 of Set 11 | amapa
# Processing Record 21 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 22 of Set 11 | pacific grove
# Processing Record 23 of Set 11 | tete
# Processing Record 24 of Set 11 | moindou
# Processing Record 25 of Set 11 | lalmohan
# Processing Record 26 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 11 | hamada
# Processing Record 28 of Set 11 | port hedland
# Processing Record 29 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 11 | padang
# Processing Record 31 of Set 11 | altay
# Processing Record 32 of Set 11 | tra vinh
# Processing Record 33 of Set 11 | aswan
# Processing Record 34 of Set 11 | hengyang
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | heilbad heiligenstadt
# Processing Record 37 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | korcula
# Processing Record 40 of Set 11 | ahmadpur
# Processing Record 41 of Set 11 | pachino
# Processing Record 42 of Set 11 | raudeberg
# Processing Record 43 of Set 11 | panaba
# Processing Record 44 of Set 11 | playa vicente
# Processing Record 45 of Set 11 | portland
# Processing Record 46 of Set 11 | rapid valley
# Processing Record 47 of Set 11 | tshikapa
# Processing Record 48 of Set 11 | corpus christi
# Processing Record 49 of Set 11 | inta
# Processing Record 50 of Set 11 | vardo
# Processing Record 1 of Set 12 | kirensk
# Processing Record 2 of Set 12 | saquena
# Processing Record 3 of Set 12 | buraydah
# Processing Record 4 of Set 12 | tromso
# Processing Record 5 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 12 | lavrentiya
# Processing Record 7 of Set 12 | amga
# Processing Record 8 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 12 | waipawa
# Processing Record 10 of Set 12 | krasnyy yar
# Processing Record 11 of Set 12 | luwuk
# Processing Record 12 of Set 12 | acworth
# Processing Record 13 of Set 12 | duluth
# Processing Record 14 of Set 12 | tomatlan
# Processing Record 15 of Set 12 | liusha
# Processing Record 16 of Set 12 | cabo san lucas
# Processing Record 17 of Set 12 | cuamba
# Processing Record 18 of Set 12 | tooele
# Processing Record 19 of Set 12 | flinders
# Processing Record 20 of Set 12 | khasan
# Processing Record 21 of Set 12 | morgan city
# Processing Record 22 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 12 | guane
# Processing Record 24 of Set 12 | monastyrshchina
# Processing Record 25 of Set 12 | porto walter
# Processing Record 26 of Set 12 | vargem grande
# Processing Record 27 of Set 12 | rambouillet
# Processing Record 28 of Set 12 | takoradi
# Processing Record 29 of Set 12 | kashan
# Processing Record 30 of Set 12 | mufulira
# Processing Record 31 of Set 12 | ola
# Processing Record 32 of Set 12 | kitzingen
# Processing Record 33 of Set 12 | samarinda
# Processing Record 34 of Set 12 | yellandu
# Processing Record 35 of Set 12 | truro
# Processing Record 36 of Set 12 | cascais
# Processing Record 37 of Set 12 | kabinda
# Processing Record 38 of Set 12 | araouane
# Processing Record 39 of Set 12 | chippewa falls
# Processing Record 40 of Set 12 | la ronge
# Processing Record 41 of Set 12 | leshukonskoye
# Processing Record 42 of Set 12 | vung tau
# Processing Record 43 of Set 12 | hofn
# Processing Record 44 of Set 12 | bandarbeyla
# Processing Record 45 of Set 12 | sarevere
# Processing Record 46 of Set 12 | erenhot
# Processing Record 47 of Set 12 | omboue
# Processing Record 48 of Set 12 | arroio grande
# Processing Record 49 of Set 12 | terney
# Processing Record 50 of Set 12 | ginir
# Processing Record 1 of Set 13 | bud
# Processing Record 2 of Set 13 | honiara
# Processing Record 3 of Set 13 | tangkak
# Processing Record 4 of Set 13 | inuvik
# Processing Record 5 of Set 13 | manicore
# Processing Record 6 of Set 13 | puri
# Processing Record 7 of Set 13 | rudnichnyy
# Processing Record 8 of Set 13 | rockport
# Processing Record 9 of Set 13 | hamilton
# Processing Record 10 of Set 13 | itarema
# Processing Record 11 of Set 13 | verkhnyaya inta
# Processing Record 12 of Set 13 | dryden
# Processing Record 13 of Set 13 | agadez
# Processing Record 14 of Set 13 | wufeng
# Processing Record 15 of Set 13 | malanje
# Processing Record 16 of Set 13 | defiance
# Processing Record 17 of Set 13 | marevo
# Processing Record 18 of Set 13 | awbari
# Processing Record 19 of Set 13 | tonota
# Processing Record 20 of Set 13 | svetlogorsk
# Processing Record 21 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 13 | henties bay
# Processing Record 23 of Set 13 | honningsvag
# Processing Record 24 of Set 13 | santona
# Processing Record 25 of Set 13 | curillo
# Processing Record 26 of Set 13 | kazachinskoye
# Processing Record 27 of Set 13 | mossendjo
# Processing Record 28 of Set 13 | ewa beach
# Processing Record 29 of Set 13 | tabas
# Processing Record 30 of Set 13 | odweyne
# Processing Record 31 of Set 13 | pietarsaari
# Processing Record 32 of Set 13 | skelleftea
# Processing Record 33 of Set 13 | aleksandrov gay
# Processing Record 34 of Set 13 | denpasar
# Processing Record 35 of Set 13 | alpena
# Processing Record 36 of Set 13 | chililabombwe
# Processing Record 37 of Set 13 | nueva guinea
# Processing Record 38 of Set 13 | enshi
# Processing Record 39 of Set 13 | salto
# Processing Record 40 of Set 13 | hare bay
# Processing Record 41 of Set 13 | houston
# Processing Record 42 of Set 13 | caravelas
# Processing Record 43 of Set 13 | san rafael
# Processing Record 44 of Set 13 | hirara
# Processing Record 45 of Set 13 | chokwe
# Processing Record 46 of Set 13 | pierre
# Processing Record 47 of Set 13 | ndele
# Processing Record 48 of Set 13 | dali
# Processing Record 49 of Set 13 | kundiawa
# Processing Record 50 of Set 13 | svarstad
# Processing Record 1 of Set 14 | yeppoon
# Processing Record 2 of Set 14 | vagur
# Processing Record 3 of Set 14 | muzhi
# Processing Record 4 of Set 14 | conde
# Processing Record 5 of Set 14 | sibolga
# Processing Record 6 of Set 14 | jian
# Processing Record 7 of Set 14 | temizhbekskiy
# Processing Record 8 of Set 14 | belaya gora
# Processing Record 9 of Set 14 | bairiki
# Processing Record 10 of Set 14 | abu zabad
# Processing Record 11 of Set 14 | liverpool
# Processing Record 12 of Set 14 | george town
# Processing Record 13 of Set 14 | faya
# Processing Record 14 of Set 14 | husavik
# Processing Record 15 of Set 14 | kavaratti
# Processing Record 16 of Set 14 | bubaque
# Processing Record 17 of Set 14 | krasnogvardeyskiy
# Processing Record 18 of Set 14 | ixtapa
# Processing Record 19 of Set 14 | genhe
# Processing Record 20 of Set 14 | serik
# Processing Record 21 of Set 14 | burley
# Processing Record 22 of Set 14 | schruns
# Processing Record 23 of Set 14 | cayenne
# Processing Record 24 of Set 14 | port hardy
# Processing Record 25 of Set 14 | prince rupert
# Processing Record 26 of Set 14 | phalaborwa
# Processing Record 27 of Set 14 | general pico
# Processing Record 28 of Set 14 | puerto colombia
# Processing Record 29 of Set 14 | ulagan
# Processing Record 30 of Set 14 | tabou
# Processing Record 31 of Set 14 | gilbues
# Processing Record 32 of Set 14 | elektrenai
# Processing Record 33 of Set 14 | porto velho
# Processing Record 34 of Set 14 | okhotsk
# Processing Record 35 of Set 14 | killybegs
# Processing Record 36 of Set 14 | cherskiy
# Processing Record 37 of Set 14 | otradnaya
# Processing Record 38 of Set 14 | muros
# Processing Record 39 of Set 14 | nadym
# Processing Record 40 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 14 | ha giang
# Processing Record 42 of Set 14 | perelyub
# Processing Record 43 of Set 14 | stornoway
# Processing Record 44 of Set 14 | karoi
# Processing Record 45 of Set 14 | dori
# Processing Record 46 of Set 14 | gornoye loo
# Processing Record 47 of Set 14 | nioro
# Processing Record 48 of Set 14 | port macquarie
# Processing Record 49 of Set 14 | chicama
# Processing Record 50 of Set 14 | laela
# Processing Record 1 of Set 15 | kirakira
# Processing Record 2 of Set 15 | yabrud
# Processing Record 3 of Set 15 | karakol
# Processing Record 4 of Set 15 | poli
# Processing Record 5 of Set 15 | villa maria
# Processing Record 6 of Set 15 | auki
# Processing Record 7 of Set 15 | forbes
# Processing Record 8 of Set 15 | masandra
# City not found. Skipping...
# Processing Record 9 of Set 15 | eydhafushi
# Processing Record 10 of Set 15 | owo
# Processing Record 11 of Set 15 | lazurne
# Processing Record 12 of Set 15 | ahipara
# Processing Record 13 of Set 15 | tautira
# Processing Record 14 of Set 15 | gaillac
# Processing Record 15 of Set 15 | olga
# Processing Record 16 of Set 15 | pires do rio
# Processing Record 17 of Set 15 | manuk mangkaw
# Processing Record 18 of Set 15 | bull savanna
# Processing Record 19 of Set 15 | pramanta
# Processing Record 20 of Set 15 | wattegama
# Processing Record 21 of Set 15 | maues
# Processing Record 22 of Set 15 | standerton
# Processing Record 23 of Set 15 | asfi
# Processing Record 24 of Set 15 | sucua
# Processing Record 25 of Set 15 | kashi
# Processing Record 26 of Set 15 | gamba
# Processing Record 27 of Set 15 | peterborough
# Processing Record 28 of Set 15 | labuhan
# Processing Record 29 of Set 15 | astoria
# Processing Record 30 of Set 15 | outlook
# Processing Record 31 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 15 | nakamura
# Processing Record 33 of Set 15 | zhurivka
# Processing Record 34 of Set 15 | newcastle
# Processing Record 35 of Set 15 | esmeraldas
# Processing Record 36 of Set 15 | port said
# Processing Record 37 of Set 15 | kloulklubed
# Processing Record 38 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 39 of Set 15 | tsaratanana
# Processing Record 40 of Set 15 | umm bab
# Processing Record 41 of Set 15 | jizan
# Processing Record 42 of Set 15 | hanzhong
# Processing Record 43 of Set 15 | alibagu
# City not found. Skipping...
# Processing Record 44 of Set 15 | seddon
# Processing Record 45 of Set 15 | kibre mengist
# Processing Record 46 of Set 15 | kieta
# Processing Record 47 of Set 15 | agropoli
# Processing Record 48 of Set 15 | santa cruz
# Processing Record 49 of Set 15 | birin
# Processing Record 50 of Set 15 | batemans bay
# Processing Record 1 of Set 16 | roebourne
# Processing Record 2 of Set 16 | puerto carreno
# Processing Record 3 of Set 16 | samarai
# Processing Record 4 of Set 16 | hlotse
# Processing Record 5 of Set 16 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 16 | roshni-chu
# Processing Record 7 of Set 16 | puerto escondido
# Processing Record 8 of Set 16 | terrace
# Processing Record 9 of Set 16 | hurghada
# Processing Record 10 of Set 16 | arrifes
# Processing Record 11 of Set 16 | nata
# Processing Record 12 of Set 16 | grand gaube
# Processing Record 13 of Set 16 | carinhanha
# Processing Record 14 of Set 16 | seminole
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Akyab      MM  20.1500   92.9000     65.57        36           0
# 1      Busselton      AU -33.6500  115.3333     66.16        58         100
# 2        Rikitea      PF -23.1203 -134.9692     79.54        65         100
# 3      Taoudenni      ML  22.6783   -3.9836     67.41        24          99
# 4         Broome      US  42.2506  -75.8330     42.48        55           0
# ..           ...     ...      ...       ...       ...       ...         ...
# 703      Arrifes      PT  37.7667  -25.7000     46.65        76          20
# 704         Nata      PA   8.3333  -80.5167     75.47        80           6
# 705  Grand Gaube      MU -20.0064   57.6608     77.40        75           4
# 706   Carinhanha      BR -14.3047  -43.7650     71.62        56           5
# 707     Seminole      US  28.7086  -81.2081     68.09        82           0
#
#      Wind Speed Current Description
# 0          6.06           clear sky
# 1          3.58     overcast clouds
# 2          3.80     overcast clouds
# 3         14.36     overcast clouds
# 4          7.00           clear sky
# ..          ...                 ...
# 703        2.30          few clouds
# 704       12.21           clear sky
# 705        1.01           clear sky
# 706        2.57           clear sky
# 707        4.61           clear sky
#
# [708 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Akyab      MM  20.1500   92.9000     65.57        36           0
# 1    Busselton      AU -33.6500  115.3333     66.16        58         100
# 2      Rikitea      PF -23.1203 -134.9692     79.54        65         100
# 3    Taoudenni      ML  22.6783   -3.9836     67.41        24          99
# 4       Broome      US  42.2506  -75.8330     42.48        55           0
# 5  Provideniya      RU  64.3833 -173.3000     -7.49        59          20
# 6        Bowen      AU -20.0167  148.2333     82.09        70         100
# 7  East London      ZA -33.0153   27.9116     75.87        92          69
# 8  Port Alfred      ZA -33.5906   26.8910     71.19        97         100
# 9        Sitka      US  57.0531 -135.3300     37.29        65         100
#
#    Wind Speed Current Description
# 0        6.06           clear sky
# 1        3.58     overcast clouds
# 2        3.80     overcast clouds
# 3       14.36     overcast clouds
# 4        7.00           clear sky
# 5        8.95          few clouds
# 6        8.93          light rain
# 7        5.84          light rain
# 8        3.00          light rain
# 9       12.66          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name='WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name)
